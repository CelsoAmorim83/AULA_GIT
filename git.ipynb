# %%
print("Aprendendo Git")
# Out:
# Aprendendo Git

# %%
nome = "Celso"
print(f"Olá, {nome}!")
# Out:
# Olá, Celso!

# %%
idade = 43
print(idade)
# Out:
# 43

# %%
cidade = "Recife"
print(f"Eu moro em {cidade}")
# Out:
# Eu moro em Recife
